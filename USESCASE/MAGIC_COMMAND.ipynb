# %% [markdown]
# #WELCOME TO DATABRICKS

# %% [markdown]
# ## PERSONAL INFO
# - $${\color{red}{SWARNA}}$$
# - **BATCH NO** - WEEKDAY 36

# %% [markdown]
# ### BATCH PIC
# ![](http://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg)

# %% [markdown]
# # USECASE

# %% [markdown]
# ##FRIST USE CASE - CREATE VOLUME

# %%
# %sql
CREATE VOLUME IF NOT EXISTS workspace.default.usage_metrics;

# %% [markdown]
# Call the notebook 4_child_nb_dataload using the magic command %run

# %%
# %run "/Workspace/Users/jakkamswarna@gmail.com/databricks-test-repo/child_nb_dataload"

# %% [markdown]
# list the file is created in the given volume or not and do the head of this file using fs magic command %fs

# %%
# %fs ls "dbfs:///Volumes/workspace/default/usage_metrics/mobile_os_usage.csv"

# %%
 # %fs head /Volumes/workspace/default/usage_metrics/mobile_os_usage.csv

# %% [markdown]
# ###
